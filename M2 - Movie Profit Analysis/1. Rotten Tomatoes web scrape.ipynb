# %%
import os
import time
import pandas as pd
import requests
import numpy as np

from selenium import webdriver
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %%
chromedriver = "/Applications/chromedriver"
os.environ['webdriver.chrome.driver'] = chromedriver
driver = webdriver.Chrome(chromedriver)

# Open webpage for movies with a Tomatometer score of 70% or below
driver.get('https://www.rottentomatoes.com/browse/dvd-streaming-all?minTomato=0&maxTomato=70&services=amazon;hbo_go;itunes;netflix_iw;vudu;amazon_prime;fandango_now&genres=1;2;4;5;6;8;9;10;11;13;18;14&sortBy=release')

# %%
# Click "Show More" button
button = driver.find_element_by_xpath('/html/body/div[6]/div[2]/div[1]/div/div[2]/div[2]/div[3]/button')
button.click()

# Click "Show More" until page bottom is reached
last_height = driver.execute_script('return document.body.scrollHeight')
while True:
    button = driver.find_element_by_xpath('/html/body/div[6]/div[2]/div[1]/div/div[2]/div[2]/div[3]/button')
    button.click()
    time.sleep(4)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# <ipython-input-3-3b305031118a>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath('/html/body/div[6]/div[2]/div[1]/div/div[2]/div[2]/div[3]/button')
# <ipython-input-3-3b305031118a>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath('/html/body/div[6]/div[2]/div[1]/div/div[2]/div[2]/div[3]/button')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3b305031118a> in <module>
#       8     button = driver.find_element_by_xpath('/html/body/div[6]/div[2]/div[1]/div/div[2]/div[2]/div[3]/button')
#       9     button.click()
# ---> 10     time.sleep(4)
#      11     new_height = driver.execute_script('return document.body.scrollHeight')
#      12     if new_height == last_height:
#
# KeyboardInterrupt:

# %%
# Import the HTML of the webpage into python  
soup = BeautifulSoup(driver.page_source, 'lxml')

# Grab the HTML of each movie
movie_card = soup.find_all('div', class_ = 'mb-movie') 

# Create a df to store scraped URLs and Tomatometer scores
url_tomatometer = pd.DataFrame({'Tomatoes URL':[''], 'Tomatometer':['']})

# Grab the URL for every movie on the page
for movie in movie_card:
    try:
        link = movie.find('a').get('href')
        tomatometer = movie.find('span', class_ = 'tMeterScore').text
        url_tomatometer = url_tomatometer.append({'Tomatoes URL':link, 'Tomatometer':tomatometer},ignore_index = True)
    except:
        pass
    
# Make full Rotten Tomatoes link in Link column
url_tomatometer['Tomatoes URL'] = 'https://www.rottentomatoes.com' + url_tomatometer['Tomatoes URL'].astype(str)

# Drop empty first row and reset index
url_tomatometer.drop(index = 0, inplace = True)
url_tomatometer = url_tomatometer.reset_index(drop=True)

# %%
# # Read in list of movies with low Tomatometer score
# url_tomatometer = pd.read_csv ('rottentomatoes70.csv',index_col=[0])

# %%
# url_tomatometer.info()
# url_tomatometer.tail(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tomatoes URL   9520 non-null   object
#  1   Title          0 non-null      object
#  2   Tomatometer    9520 non-null   object
#  3   Year           0 non-null      object
#  4   N_Tomatometer  0 non-null      object
# dtypes: object(5)
# memory usage: 446.2+ KB
#                                            Tomatoes URL Title Tomatometer  \
# 9470  https://www.rottentomatoes.com/m/1003075-brews...  None         35%
# 9471          https://www.rottentomatoes.com/m/daylight  None         27%
# 9472          https://www.rottentomatoes.com/m/star_kid  None         43%
# 9473      https://www.rottentomatoes.com/m/pretty_woman  None         64%
# 9474   https://www.rottentomatoes.com/m/1072385-kingpin  None         50%
# 9475   https://www.rottentomatoes.com/m/dead_presidents  None         45%
# 9476    https://www.rottentomatoes.com/m/last_boy_scout  None         46%
# 9477         https://www.rottentomatoes.com/m/lifeforce  None         57%
# 9478  https://www.rottentomatoes.com/m/starship_troo...  None         66%
# 9479             https://www.rottentomatoes.com/m/spawn  None         17%
# 9480      https://www.rottentomatoes.com/m/passenger_57  None         24%
# 9481        https://www.rottentomatoes.com/m/red_corner  None         30%
# 9482  https://www.rottentomatoes.com/m/desperate_mea...  None         19%
# 9483             https://www.rottentomatoes.com/m/mimic  None         64%
# 9484      https://www.rottentomatoes.com/m/exterminator  None         38%
# 9485  https://www.rottentomatoes.com/m/kama_sutra_a_...  None         40%
# 9486   https://www.rottentomatoes.com/m/1047985-getaway  None         30%
# 9487           https://www.rottentomatoes.com/m/fortune  None         29%
# 9488  https://www.rottentomatoes.com/m/vampires_sedu...  None         40%
# 9489             https://www.rottentomatoes.com/m/evita  None         63%
# 9490  https://www.rottentomatoes.com/m/fairy_tale_a_...  None         57%
# 9491   https://www.rottentomatoes.com/m/1022576-victory  None         63%
# 9492      https://www.rottentomatoes.com/m/1006364-dune  None         44%
# 9493  https://www.rottentomatoes.com/m/man_who_knew_...  None         39%
# 9494     https://www.rottentomatoes.com/m/happy_gilmore  None         61%
# 9495     https://www.rottentomatoes.com/m/lady_in_white  None         69%
# 9496  https://www.rottentomatoes.com/m/1078216-pictu...  None         47%
# 9497       https://www.rottentomatoes.com/m/dragonheart  None         50%
# 9498  https://www.rottentomatoes.com/m/kull_the_conq...  None         25%
# 9499      https://www.rottentomatoes.com/m/airport_1975  None         29%
# 9500              https://www.rottentomatoes.com/m/bean  None         44%
# 9501  https://www.rottentomatoes.com/m/look_whos_tal...  None         57%
# 9502  https://www.rottentomatoes.com/m/my_stepmother...  None         19%
# 9503     https://www.rottentomatoes.com/m/guarding_tess  None         57%
# 9504      https://www.rottentomatoes.com/m/multiplicity  None         43%
# 9505   https://www.rottentomatoes.com/m/rooster_cogburn  None         50%
# 9506  https://www.rottentomatoes.com/m/1079716-seven...  None         60%
# 9507  https://www.rottentomatoes.com/m/conan_the_des...  None         25%
# 9508           https://www.rottentomatoes.com/m/con_air  None         56%
# 9509       https://www.rottentomatoes.com/m/u_turn_1997  None         61%
# 9510      https://www.rottentomatoes.com/m/gang_related  None         53%
# 9511  https://www.rottentomatoes.com/m/1056079-speci...  None          7%
# 9512       https://www.rottentomatoes.com/m/double_team  None         11%
# 9513    https://www.rottentomatoes.com/m/judgment_night  None         35%
# 9514  https://www.rottentomatoes.com/m/1079718-one_n...  None         32%
# 9515        https://www.rottentomatoes.com/m/maniac_cop  None         50%
# 9516        https://www.rottentomatoes.com/m/devils_own  None         35%
# 9517  https://www.rottentomatoes.com/m/single_white_...  None         53%
# 9518  https://www.rottentomatoes.com/m/high_school_high  None         19%
# 9519            https://www.rottentomatoes.com/m/asphyx  None         67%
#
#       Year N_Tomatometer
# 9470  None          None
# 9471  None          None
# 9472  None          None
# 9473  None          None
# 9474  None          None
# 9475  None          None
# 9476  None          None
# 9477  None          None
# 9478  None          None
# 9479  None          None
# 9480  None          None
# 9481  None          None
# 9482  None          None
# 9483  None          None
# 9484  None          None
# 9485  None          None
# 9486  None          None
# 9487  None          None
# 9488  None          None
# 9489  None          None
# 9490  None          None
# 9491  None          None
# 9492  None          None
# 9493  None          None
# 9494  None          None
# 9495  None          None
# 9496  None          None
# 9497  None          None
# 9498  None          None
# 9499  None          None
# 9500  None          None
# 9501  None          None
# 9502  None          None
# 9503  None          None
# 9504  None          None
# 9505  None          None
# 9506  None          None
# 9507  None          None
# 9508  None          None
# 9509  None          None
# 9510  None          None
# 9511  None          None
# 9512  None          None
# 9513  None          None
# 9514  None          None
# 9515  None          None
# 9516  None          None
# 9517  None          None
# 9518  None          None
# 9519  None          None

# %%
# Add new columns to be filled in next Rotten Tomatoes scrape
url_tomatometer['Title'] = None
url_tomatometer['Year'] = None
url_tomatometer['N_Tomatometer'] = None

# %%
for index, row in url_tomatometer.iterrows():
    url = url_tomatometer.iloc[index,0] # Retrieves the IMDB url to search for
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'lxml') # Imports the HTML of the webpage into python 
    time.sleep(2) 
            
    scoreboard = soup.find('score-board',class_='scoreboard')

    try:
        title=scoreboard.find('h1',{'data-qa':'score-panel-movie-title'}).text  
        url_tomatometer['Title'][index]=title
    except:
        title = np.nan 
    
    try:
        year=scoreboard.find('p',class_='scoreboard__info').text 
        url_tomatometer['Year'][index]=year
    except:
        year = np.nan
    
    try:
        n_tomatometer=scoreboard.find('a',{'data-qa':'tomatometer-review-count'}).text 
        url_tomatometer['N_Tomatometer'][index]=n_tomatometer
    except:
        n_tomatometer = np.nan
    
# Export the dataframe as a csv
url_tomatometer.to_csv('rotten_df.csv')
